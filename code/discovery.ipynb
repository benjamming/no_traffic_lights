# %%
import pandas as pd
from pandasql import sqldf
import pyparsing as pyp
from os import path
import string

INTERSECTION_IN = '../data/raw/Jefferson_County_KY_Street_Intersections.csv'
assert path.exists(INTERSECTION_IN)

XS = pd.read_csv(INTERSECTION_IN)

STOPLIGHTS_IN = '../data/raw/Jefferson_County_KY_Signalized_Intersections.csv'
assert path.exists(STOPLIGHTS_IN)

STOPS = pd.read_csv(STOPLIGHTS_IN)

# %%
XS.columns, STOPS.columns
# Out:
# (Index(['X', 'Y', 'OBJECTID', 'SIFCODE1', 'SIFCODE2', 'INTID', 'SCCAD_ID',
#         'FST_INTPRE', 'FST_INTNAME', 'FST_INTSUF', 'SEC_INTPRE', 'SEC_INTNAME',
#         'SEC_INTSUF', 'X_COORD', 'Y_COORD', 'FST_SIFID', 'SEC_SIFID',
#         'GLOBALID'],
#        dtype='object'),
#  Index(['X', 'Y', 'OBJECTID', 'UNITID', 'SIGID', 'MAINSTREET', 'CROSSSTREET',
#         'OWNER2', 'ROUTE', 'MILEPOINT', 'DESCRIPTION', 'TIMES', 'OWNER', 'TYPE',
#         'INTID', 'ATMSID'],
#        dtype='object'))

# %%
XS['INTID'] = XS.INTID.str.strip()
STOPS['INTID'] = STOPS.INTID.str.strip()

# %%
# Easy to match
easy_match = XS[XS.INTID.isin(STOPS.INTID)]

# %%
easy = sqldf("""SELECT XS.INTID, XS.FST_INTNAME, XS.SEC_INTNAME, STOPS.MAINSTREET, STOPS.CROSSSTREET, STOPS.DESCRIPTION
      FROM XS JOIN STOPS
      ON XS.INTID == STOPS.INTID""")
easy.head()
# Out:
#          INTID  FST_INTNAME      SEC_INTNAME   MAINSTREET      CROSSSTREET  \
# 0  16340775940       JUNEAU      SHELBYVILLE       JUNEAU      SHELBYVILLE
# 1  16790939409   DATA VAULT  ENGLISH STATION   DATA VAULT  ENGLISH STATION
# 2  18059409996  SHELBYVILLE       I 265 RAMP  SHELBYVILLE       I 265 RAMP
# 3  28012247132      COLLINS         WESTPORT      COLLINS         WESTPORT
# 4  28110531224  CHAMBERLAIN          COLLINS  CHAMBERLAIN          COLLINS
#
#                     DESCRIPTION
# 0          JUNEAU @ SHELBYVILLE
# 1  DATA VAULT @ ENGLISH STATION
# 2      SHELBYVILLE @ I 265 RAMP
# 3            COLLINS @ WESTPORT
# 4         CHAMBERLAIN @ COLLINS

# %%
# Not so easy to match
intid_2 = sqldf("SELECT * FROM STOPS WHERE STOPS.INTID = 2")
intid_2


hard = sqldf("""SELECT XS.INTID, XS.FST_INTNAME, XS.SEC_INTNAME, intid_2.MAINSTREET, intid_2.CROSSSTREET, intid_2.DESCRIPTION
      FROM XS JOIN intid_2
      ON (XS.FST_INTNAME == intid_2.MAINSTREET)
      AND XS.SEC_INTNAME == intid_2.CROSSSTREET""")
hard.head()
# Out:
#           INTID  FST_INTNAME     SEC_INTNAME   MAINSTREET     CROSSSTREET  \
# 0  779103840827    BARDSTOWN         BUECHEL    BARDSTOWN         BUECHEL
# 1  824403847291    BARDSTOWN       WATTERSON    BARDSTOWN       WATTERSON
# 2  824403847355    BARDSTOWN       WATTERSON    BARDSTOWN       WATTERSON
# 3  825621905945  FERN VALLEY  SHEPHERDSVILLE  FERN VALLEY  SHEPHERDSVILLE
# 4  840103840751    BARDSTOWN         BUECHEL    BARDSTOWN         BUECHEL
#
#                     DESCRIPTION
# 0           BARDSTOWN @ BUECHEL
# 1         BARDSTOWN @ WATTERSON
# 2         BARDSTOWN @ WATTERSON
# 3  FERN VALLEY @ SHEPHERDSVILLE
# 4           BARDSTOWN @ BUECHEL

# %%
def parse_description(description:str):
    main, cross = description.split("@")
    return main.strip(), cross.strip()

def verifier(fst_intname, sec_intname, main_street, cross_street, description):
    desc_main, desc_cross = parse_description(description)
    return all((
        fst_intname == main_street,
        sec_intname == cross_street,
        fst_intname == desc_main,
        sec_intname == desc_cross))

def verify_row(row):
    test = True
    try:
        desc_main, desc_cross = parse_description(row.DESCRIPTION)
    except AttributeError:
        pass
    except ValueError:
        pass
    else:
        test &= row.FST_INTNAME == desc_main
        test &= row.SEC_INTNAME == desc_cross
        
    test &= row.FST_INTNAME == row.MAINSTREET
    test &= row.SEC_INTNAME == row.CROSSSTREET
    
    return test

parse_description("POPLAR LEVEL @ JEFFERSON")
verifier("BARDSTOWN", "BUECHEL", "BARDSTOWN", "BUECHEL", "BARDSTOWN @ BUECHEL")
verify_row(easy.loc[0])
# Out:
# True

# %%
easy[easy.apply(verify_row, axis=1) == True] # Most of these work
not_so_easy = easy[easy.apply(verify_row, axis=1) == False]
not_so_easy
# Out:
#               INTID     FST_INTNAME         SEC_INTNAME         MAINSTREET  \
# 5       2834756E294       OLD HENRY      TERRA CROSSING       OLD HENRY RD
# 13      76547569996       OLD HENRY          I 265 RAMP       OLD HENRY RD
# 46     181871327354        WESTPORT            WESTPORT        WESTPORT RD
# 108    433648057132          ORMSBY            WESTPORT        WESTPORT RD
# 120    460407638870          BUNSEN              BUNSEN         BUNSEN PKY
# 126    477491259183     HURSTBOURNE         HURSTBOURNE    HURSTBOURNE PKY
# 155    532306561717    BRECKENRIDGE           DUTCHMANS    BRECKENRIDGE LN
# 161    545817179463       DUTCHMANS           DUTCHMANS      DUTCHMANS PKY
# 164    560830429126     HURSTBOURNE         HURSTBOURNE  S HURSTBOURNE PKY
# 194    698671329996        WESTPORT          I 265 RAMP        WESTPORT RD
# 216    81666394D188    TAYLORSVILLE       PLEASANT GLEN    TAYLORSVILLE RD
# 219    822801889996        BILLTOWN          I 265 RAMP        BILLTOWN RD
# 239    978905189996   BEULAH CHURCH          I 265 RAMP   BEULAH CHURCH RD
# 241   1008903846465       BARDSTOWN             THIXTON       BARDSTOWN RD
# 252   1083147556394       OLD HEADY        TAYLORSVILLE    TAYLORSVILLE RD
# 266   1159546326026          SMYRNA              SMYRNA         OUTER LOOP
# 286   1217075539999            ZORN           I 71 RAMP           ZORN AVE
# 299   1263960066007            16TH                16TH          W MAIN ST
# 301   1264422032204            15TH                15TH          W MAIN ST
# 319   1278855356448      RIVER PARK                35TH               34TH
# 378   1324006570658    BRECKINRIDGE        BRECKINRIDGE  W BRECKINRIDGE ST
# 453   1372807740775         BURNETT             BURNETT      W BURNETT AVE
# 557   1552033513352         JOHNSON             JOHNSON          E MAIN ST
# 587   1560211661167            CLAY                CLAY          E MAIN ST
# 690   1642611131114        CHESTNUT            CHESTNUT      W CHESTNUT ST
# 704   1646607010702        BROADWAY            BROADWAY         W BROADWAY
# 747   1671123042305             4TH                 4TH          W MAIN ST
# 776   1675719084139  CLARK MEMORIAL                MAIN            MAIN ST
# 777   1675922222223             1ST                 1ST           N 1ST ST
# 778   1676007060707           BROOK               BROOK          E MAIN ST
# 779   1676122532254           FLOYD               FLOYD          E MAIN ST
# 780   1676242145872          MARKET                 2ND          MARKET ST
# 862   1806828949995         HERBERT          I 264 RAMP          DIXIE HWY
# 957   2091832354163        MANSLICK            MANSLICK        MANSLICK RD
# 1057  28937F247D258       BROAD RUN  HIDDEN VALLEY FARM       BARDSTOWN RD
#
#               CROSSSTREET                         DESCRIPTION
# 5     TERRA CROSSING BLVD     OLD HENRY @ TERRA CROSSING BLVD
# 13          I 265 SB RAMP        OLD HENRY RD @ I 265 SB RAMP
# 46           WESTPORT CIR          WESTPORT RD @ WESTPORT CIR
# 108             ORMSBY LN                   WESTPORT @ ORMSBY
# 120          PLANTSIDE DR           BUNSEN PKY @ PLANTSIDE DR
# 126      HURSTBOURNE TRCE  HURSTBOURNE PKY @ HURSTBOURNE TRCE
# 155          DUTCHMANS LN      BRECKENRIDGE LN @ DUTCHMANS LN
# 161          DUTCHMANS LN        DUTCHMANS PKY @ DUTCHMANS LN
# 164           HURSTBOURNE     S HURSTBOURNE PKY @ HURSTBOURNE
# 194            I 265 RAMP            WESTPORT RD @ I 265 RAMP
# 216      PLEASANT GLEN DR  TAYLORSVILLE RD @ PLEASANT GLEN DR
# 219            I 265 RAMP            BILLTOWN RD @ I 265 RAMP
# 239            I 265 RAMP       BEULAH CHURCH RD @ I 265 RAMP
# 241            THIXTON LN           BARDSTOWN RD @ THIXTON LN
# 252          OLD HEADY RD      TAYLORSVILLE RD @ OLD HEADY RD
# 266           SMYRNA PKWY            OUTER LOOP @ SMYRNA PKWY
# 286             I 71 RAMP                                None
# 299             N 16TH ST               W MAIN ST @ N 16TH ST
# 301             N 15TH ST               W MAIN ST @ N 15TH ST
# 319            RIVER PARK                   34TH @ RIVER PARK
# 378              S 1ST ST        W BRECKINRIDGE ST @ S 1ST ST
# 453              S 1ST ST            W BURNETT AVE @ S 1ST ST
# 557          S JOHNSON ST            E MAIN ST @ S JOHNSON ST
# 587             S CLAY ST               E MAIN ST @ S CLAY ST
# 690              S 1ST ST            W CHESTNUT ST @ S 1ST ST
# 704              S 1ST ST               W BROADWAY @ S 1ST ST
# 747              N 4TH ST                W MAIN ST @ N 4TH ST
# 776              S 2ND ST                  MAIN ST @ S 2ND ST
# 777             W MAIN ST                N 1ST ST @ W MAIN ST
# 778            N BROOK ST              E MAIN ST @ N BROOK ST
# 779              FLOYD ST                E MAIN ST @ FLOYD ST
# 780              S 2ND ST                MARKET ST @ S 2ND ST
# 862       I 264 WEST RAMP         DIXIE HWY @ I 264 WEST RAMP
# 957         MANSLICK BLVD         MANSLICK RD @ MANSLICK BLVD
# 1057        BROAD RUN PKY        BARDSTOWN RD @ BROAD RUN PKY

# %%
prefixes = {x for x in XS.FST_INTPRE.str.strip().unique() if x}
prefixes.union([x for x in XS.SEC_INTPRE.str.strip().unique() if x])

suffixes = {s for s in XS.FST_INTSUF.str.strip().unique() if s}
suffixes.union({s for s in XS.SEC_INTSUF.str.strip().unique() if s})

def strip_roadname(roadname:str) -> str:
    for prefix in prefixes:
        new = roadname.lstrip(prefix)
    for suffix in suffixes:
        new = new.strip(suffix)
    return new.strip()

strip_roadname("OLD HENRY RD")
# Out:
# 'HENRY'

# %%
hard[hard.apply(verify_row, axis=1) == False] # This is empty, which is what I want.
# Out:
# Empty DataFrame
# Columns: [INTID, FST_INTNAME, SEC_INTNAME, MAINSTREET, CROSSSTREET, DESCRIPTION]
# Index: []

# %%
easy_match = sqldf("""SELECT XS.INTID as XS_INTID, XS.FST_INTNAME, XS.SEC_INTNAME,
            STOPS.INTID as STOPS_INTID, STOPS.MAINSTREET, STOPS.CROSSSTREET
      FROM XS JOIN STOPS
      ON XS.INTID = STOPS.INTID""")
start = 100
easy_match[easy_match.FST_INTNAME.isin(easy_match.MAINSTREET)].loc[start:start+10]
# Out:
#          XS_INTID     FST_INTNAME   SEC_INTNAME   STOPS_INTID      MAINSTREET  \
# 100  388108272930         BUECHEL         HIKES  388108272930         BUECHEL
# 101  391606566005    BRECKENRIDGE      SIX MILE  391606566005    BRECKENRIDGE
# 102  400067127413  U S HIGHWAY 42     WOODSTONE  400067127413  U S HIGHWAY 42
# 103  418544927132          MURPHY      WESTPORT  418544927132          MURPHY
# 104  418910537132     CHAMBERLAIN      WESTPORT  418910537132     CHAMBERLAIN
# 105  487976248353    BLANKENBAKER  COMMONWEALTH  487976248353    BLANKENBAKER
# 106  488719907293       EVERGREEN      WOODLAND  488719907293       EVERGREEN
# 107  428707248262      BROWNSBORO       BARBOUR  428707248262      BROWNSBORO
# 108  433648057132          ORMSBY      WESTPORT  433648057132     WESTPORT RD
# 109  435827747132          LYNDON      WESTPORT  435827747132          LYNDON
# 110  436629017132            HERR      WESTPORT  436629017132            HERR
#
#       CROSSSTREET
# 100         HIKES
# 101      SIX MILE
# 102     WOODSTONE
# 103      WESTPORT
# 104      WESTPORT
# 105  COMMONWEALTH
# 106      WOODLAND
# 107       BARBOUR
# 108     ORMSBY LN
# 109      WESTPORT
# 110      WESTPORT

# %%
names = pd.DataFrame(columns='STOPS XS'.split())
names['STOPS'] = pd.concat((STOPS.MAINSTREET, STOPS.CROSSSTREET)).dropna().unique()

xs_names = pd.concat((XS.FST_INTNAME, XS.SEC_INTNAME)).dropna().unique()
xs_names

for i, data in names.iterrows():
    name = data.STOPS
    match = list()
    for xsname in xs_names:
        if xsname in name:
            match.append(xsname)
    names.at[i, 'XS'] = match

names
# Out:
#                    STOPS                                     XS
# 0              OLD HENRY                  [OLD HENRY, HENRY, H]
# 1            SHELBYVILLE               [SHELBYVILLE, SHELBY, H]
# 2             BROWNSBORO            [BROWNSBORO, BROWN, BROWNS]
# 3                   HERR                              [HERR, H]
# 4         U S HIGHWAY 42  [U S HIGHWAY 42, HIGH, H, HIGHWAY 42]
# ..                   ...                                    ...
# 619           THIXTON LN                           [THIXTON, H]
# 620        I 265 SB RAMP                                    [M]
# 621         OLD HEADY RD                  [HEADY, OLD HEADY, H]
# 622            ORMSBY LN                            [ORMSBY, M]
# 623  TERRA CROSSING BLVD          [CROSS, TERRA CROSSING, ROSS]
#
# [624 rows x 2 columns]
